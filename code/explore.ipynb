# %% [markdown]
# # Bill Splitter — Notebook
#
# This notebook is the **notebook interface** for the Bill Splitter. Like the
# console and Streamlit apps, it does no math of its own — it imports `bill.py`
# and calls its functions to explore different tips.
#
# Run each cell with **Shift+Enter** (choose the `/usr/local/bin/python` kernel the
# first time), or use **Run All**.

# %%
# %pip install pandas
import pandas as pd

import bill
# Out:
# Requirement already satisfied: pandas in /workspace/.venv/lib/python3.13/site-packages (3.0.5)
# Requirement already satisfied: numpy>=1.26.0 in /workspace/.venv/lib/python3.13/site-packages (from pandas) (2.5.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /workspace/.venv/lib/python3.13/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /workspace/.venv/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
#
# [notice] A new release of pip is available: 26.1.2 -> 26.2.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# One example: a $50 bill, a 20% tip, split 4 ways.
subtotal, pct, people = 50.0, 20, 4
total = bill.grand_total(subtotal, pct)
per_person = bill.split_evenly(total, people)

print(f"Grand total: ${total:.2f}")
print(f"Each of {people} pays: ${per_person:.2f}")
per_person
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 6
#       2 subtotal, pct, people = 50.0, 20, 4
#       3 total = bill.grand_total(subtotal, pct)
#       4 per_person = bill.split_evenly(total, people)
#       5
# ----> 6 print(f"Grand total: ${total:.2f}")
#       7 print(f"Each of {people} pays: ${per_person:.2f}")
#       8 per_person
#
# TypeError: unsupported format string passed to NoneType.__format__

# %%
# Compare the per-person cost across a range of tip percentages.
percents = [10, 15, 18, 20, 25]
table = pd.DataFrame(
    {"per person": [bill.split_evenly(bill.grand_total(subtotal, p), people) for p in percents]},
    index=[f"{p}%" for p in percents],
)
table
# Out:
#     per person
# 10%       None
# 15%       None
# 18%       None
# 20%       None
# 25%       None

# %%
# A quick bar chart of the same data.
table.plot(kind="bar", legend=False, title="Per-person cost by tip %")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[9], line 2
#       1 # A quick bar chart of the same data.
# ----> 2 table.plot(kind="bar", legend=False, title="Per-person cost by tip %")
#
# File /workspace/.venv/lib/python3.13/site-packages/pandas/plotting/_core.py:1105, in PlotAccessor.__call__(self, *args, **kwargs)
#    1104 def __call__(self, *args, **kwargs):
# -> 1105     plot_backend = _get_plot_backend(kwargs.pop("backend", None))
#    1107     x, y, kind, kwargs = self._get_call_args(
#    1108         plot_backend.__name__, self._parent, args, kwargs
#    1109     )
#    1111     kind = self._kind_aliases.get(kind, kind)
#
# File /workspace/.venv/lib/python3.13/site-packages/pandas/plotting/_core.py:2253, in _get_plot_backend(backend)
#    2250 if backend_str in _backends:
#    2251     return _backends[backend_str]
# -> 2253 module = _load_backend(backend_str)
#    2254 _backends[backend_str] = module
#    2255 return module
#
# File /workspace/.venv/lib/python3.13/site-packages/pandas/plotting/_core.py:2183, in _load_backend(backend)
#    2181         module = importlib.import_module("pandas.plotting._matplotlib")
#    2182     except ImportError:
# -> 2183         raise ImportError(
#    2184             "matplotlib is required for plotting when the "
#    2185             'default backend "matplotlib" is selected.'
#    2186         ) from None
#    2187     return module
#    2189 found_backend = False
#
# ImportError: matplotlib is required for plotting when the default backend "matplotlib" is selected.
